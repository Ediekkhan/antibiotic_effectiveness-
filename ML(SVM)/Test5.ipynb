# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
import streamlit as st

# Load and prepare data
data = pd.read_csv("/home/Kanex/Documents/dr An/ML(SVM)/Large_files/editedDiagnosis.csv")
features = ["diagnosis", "drugs"]  # Adjust based on your data
target = "result"  # Replace with your effectiveness label

# %%
data.head(10)
# Out:
#    Unnamed: 0                                 diagnosis  \
# 0           0  Severe plasmodiasis / febrile convulsion
# 1           1                         Malaria/pertussis
# 2           2                             ENTERIC FEVER
# 3           3                Appendicitis/appendix mass
# 4           4                           Neonatal sepsis
# 5           5        bronchopneumonia /intestinal colic
# 6           6                          bronchopneumonia
# 7           7                 Hepatomegaly/plasmodiasis
# 8           8                          Bronchial asthma
# 9           9                    Sub-acute appendicitis
#
#                                                drugs result
# 0                             Ceftriaxone/gentamicin      A
# 1                                        Ceftriaxone      A
# 2                             Ceftriaxone/gentamicin      A
# 3                     Ceftriaxone/intravenous flagyl      A
# ...

# %%
# One-hot encode categorical features
categorical_features = ["diagnosis" , "drugs"] 
encoder = OneHotEncoder(sparse=False)  # Adjust "sparse" parameter if needed
encoded_features = pd.DataFrame(encoder.fit_transform(data[categorical_features]))
